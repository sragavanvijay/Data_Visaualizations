# %%
! pip install graphviz
! pip install dot
import datetime
from datetime import datetime
from PIL import Image
from graphviz import Digraph
dot= Digraph(comment="aa")
dot
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/1f/e2/ef2581b5b86625657afd32030f90cf2717456c1d2b711ba074bf007c0f1a/graphviz-0.10.1-py2.py3-none-any.whl
# ...
#   Could not find a version that satisfies the requirement dot (from versions: )
# No matching distribution found for dot
# FileNotFoundErrorTraceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/graphviz/backend.py in run(cmd, input, capture_output, check, quiet, **kwargs)
#     146     try:
# --> 147         proc = subprocess.Popen(cmd, startupinfo=get_startupinfo(), **kwargs)
#     148     except OSError as e:
#
# /opt/conda/lib/python3.6/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     708                                 errread, errwrite,
# ...

# %%
#! pip install graphviz

# %%
f = Digraph('audit_tie_out')
f.edge('Landing_Path', 'Processing_Engine', label='')
f.edge('Processing_Engine', 'Data_Cleansing', label='File Name Standardisation')
f.edge('Data_Cleansing', 'PDF_2_TXT_Extraction', label='')
f.edge('Data_Cleansing', 'XL_2_TXT_Extraction', label='')
f.edge('PDF_2_TXT_Extraction', 'PDF_Table_Extraction', label='')
f.edge('XL_2_TXT_Extraction', 'XL_Sheets_2_Files', label='')
f.edge('PDF_Table_Extraction', 'Datetime_Folder_Creation', label='')
f.edge('XL_Sheets_2_Files', 'Datetime_Folder_Creation', label='')
f.edge('Datetime_Folder_Creation', 'Processed_File_Copy', label='')
f.edge('Processed_File_Copy', 'Raw_File_Copy', label='')
f.edge('Raw_File_Copy', 'Landing_Folder_Cleanup', label='')
f
#f.render(filename='aka.jpg')
# Out:
# FileNotFoundErrorTraceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/graphviz/backend.py in run(cmd, input, capture_output, check, quiet, **kwargs)
#     146     try:
# --> 147         proc = subprocess.Popen(cmd, startupinfo=get_startupinfo(), **kwargs)
#     148     except OSError as e:
#
# /opt/conda/lib/python3.6/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     708                                 errread, errwrite,
# --> 709                                 restore_signals, start_new_session)
#     710         except:
#
# /opt/conda/lib/python3.6/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
# ...

# %%
g = Digraph('Platform')
g.edge('UX', 'Storage', label='To Do')
g.edge('Storage', 'Processing_Engine', label='Connected')
g.edge('Processing_Engine', 'storage', label='Connected')


g.edge('Big_Query', 'Google_sheets', label='Synced')
g.edge('Google_sheets', 'big_Query', label='Synced')

#g.edge('PDF_2_TXT_Extraction', 'PDF_Table_Extraction', label='')
#g.edge('XL_2_TXT_Extraction', 'XL_Sheets_2_Files', label='')
#g.edge('PDF_Table_Extraction', 'Datetime_Folder_Creation', label='')
#g.edge('XL_Sheets_2_Files', 'Datetime_Folder_Creation', label='')
#g.edge('Datetime_Folder_Creation', 'Processed_File_Copy', label='')
#g.edge('Processed_File_Copy', 'Raw_File_Copy', label='')
#g.edge('Raw_File_Copy', 'Landing_Folder_Cleanup', label='')
#g.render(filename='aka.jpg')

# %% [markdown]
# # Architecture

# %%
a = Digraph('Platform')
c=Digraph('cluster_0')
c.body.append('style=filled')
c.body.append('color=lightgrey')
c.node_attr.update(style='filled',color='white')
c.edges([('File Upload','PDF')])
c.edges([('File Upload','Excel')])
c.edge('PDF', 'Extraction', label='')
c.edge('Excel', 'extraction', label='')
c.edge('Extraction', 'Converted_Text', label='')
c.edge('extraction', 'Converted_text', label='')

d=Digraph('cluster_1')
d.body.append('style=filled')
d.body.append('color=lightgrey')
d.node_attr.update(style='filled',color='white')

d.edge('Output DataFrames(Results)', 'Storage(stored for given time)', label='')
d.edge('Output DataFrames(Results)', 'Tables(for futher analysis)', label='')


c.body.append('label = ""')
d.body.append('label = ""')
a.subgraph(c)
a.subgraph(d)



a.edge('UX', 'File Upload', label='')
a.edge('Converted_text', 'NLP Engine', label='')
a.edge('Converted_Text', 'NLP Engine', label='')
a.edge('NLP Engine', 'Output DataFrames(Results)', label='')
a.edge('UX_Output_screen', 'User_Download', label='')
a.edge('Output DataFrames(Results)', 'UX_Output_screen', label='')


a
#a.render(filename='Audit_tie_out.jpg')

# %%
f = Digraph('Piller-3')
f.edge('PIT', 'Source', label='SQOOP')
f.edge('Source', 'DIL', label='Script-xyz')
f.edge('DIL', 'Enrich', label='Script-xyz1')
f.edge('DIL', 'GDW 2.0', label='Script-xyz2')
f.edge('GDW 2.0', 'GTRS', label='Script-xyz2')
f.edge('GDW 2.0', 'CDE', label='Script-xyz2')
f.edge('DIL', 'CDE', label='Script-xyz2')
f.edge('GTRS', 'CDE', label='Script-xyz2')

f
